# %% [markdown]
# <a href="https://colab.research.google.com/github/EladWarshawsky/Easy-Apply-Automater/blob/main/Splice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from google.colab import files
from pathlib import Path
import imghdr
# Out:
# <ipython-input-1-5f006e61a5cb>:5: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
# !git clone https://github.com/omerbt/Splice.git
# Out:
# Cloning into 'Splice'...
# remote: Enumerating objects: 1382, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 1382 (delta 25), reused 50 (delta 23), pack-reused 1321 (from 1)
# Receiving objects: 100% (1382/1382), 210.52 MiB | 18.63 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
#@title Create/Reset Dataroot

os.chdir("/content/Splice")

DATAROOT = "./datasets/curr_pair"
path_dataroot = Path(DATAROOT)
if os.path.exists(path_dataroot):
  shutil.rmtree(path_dataroot)
path_A = Path(f"{DATAROOT}/A")
path_B = Path(f"{DATAROOT}/B")
path_A.mkdir(parents=True, exist_ok=True)
path_B.mkdir(parents=True, exist_ok=True)

# %%
#@title Create Utils
from IPython.display import display
from torchvision.transforms import Resize
from PIL import Image


def display_image(img):
  w, h = img.size
  if max(w, h) > 480:
    img = Resize(480, max_size=481)(img)
  display(img)


def process_upload(uploaded, data_path):
  if len(uploaded.keys()) > 1:
    clear_output(wait=True)
    for fn in uploaded.keys():
      os.remove(fn)
    print("Please choose 1 file!")
  else:
    fn = list(uploaded.keys())[0]
    if imghdr.what(fn) is None:
      clear_output(wait=True)
      print("Please upload a valid image file")
      os.remove(fn)
    else:
      dest_path = f"{data_path}/{fn}"
      shutil.move(fn, dest_path)
      clear_output(wait=True)
      print("Image successfully uploaded:")
      uploaded_image = Image.open(dest_path)
      display_image(uploaded_image)

# %%
#@title Upload Source Structure Image
from IPython.display import clear_output

shutil.rmtree(path_A)
path_A.mkdir(parents=True)
uploaded = files.upload()
process_upload(uploaded, f"{DATAROOT}/A")
# Out:
# Image successfully uploaded:
# <PIL.Image.Image image mode=RGB size=481x364>

# %%
#@title Upload Target Appearance Image
shutil.rmtree(path_B)
path_B.mkdir(parents=True)
uploaded = files.upload()
process_upload(uploaded, f"{DATAROOT}/B")
# Out:
# Image successfully uploaded:
# <PIL.Image.Image image mode=RGB size=342x481>

# %%
#@title Perform Splicing

from train import train_model
from torchvision.transforms import ToPILImage, Resize

def show_result(out_img):
  clear_output(wait=True)
  img = ToPILImage()(out_img)
  display_image(img)


train_model(DATAROOT, show_result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-39e0bce13b24> in <cell line: 0>()
#      10
#      11
# ---> 12 train_model(DATAROOT, show_result)
#
# /content/Splice/train.py in train_model(dataroot, callback)
#      26     if seed == -1:
#      27         seed = np.random.randint(2 ** 32 - 1, dtype=np.int64)
# ---> 28     random.seed(seed)
#      29     np.random.seed(seed)
#      30     torch.manual_seed(seed)
#
# /usr/lib/python3.11/random.py in seed(self, a, version)
#     158
#     159         elif not isinstance(a, (type(None), int, float, str, bytes, bytearray)):
# --> 160             raise TypeError('The only supported seed types are: None,\n'
#     161                             'int, float, str, bytes, and bytearray.')
#     162
#
# TypeError: The only supported seed types are: None,
# int, float, str, bytes, and bytearray.
